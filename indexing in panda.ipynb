# %%
import pandas as pd
netflix =pd.read_csv('./Netflix subscription fee Dec-2021 - Netflix subscription fee Dec-2021.csv')

pd.set_option('display.max.row', 20)

#netflix.head(20)

netflix.tail()
# Out:
#    Country_code         Country  Total Library Size  No. of TV Shows  \
# 60           ua         Ukraine                5336             3261
# 61           gb  United Kingdom                6643             4551
# 62           us   United States                5818             3826
# 63           uy         Uruguay                4989             3154
# 64           ve       Venezuela                4797             3154
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 60           2075                        5.64                           8.46
# 61           2092                        7.91                          13.20
# 62           1992                        8.99                          13.99
# 63           1835                        8.99                          12.99
# 64           1643                        7.99                          10.99
#
#     Cost Per Month - Premium ($)
# 60                         11.29
# ...

# %%
netflix.describe()
# Out:
#        Total Library Size  No. of TV Shows  No. of Movies  \
# count           65.000000        65.000000      65.000000
# mean          5314.415385      3518.953846    1795.461538
# ...                   ...              ...            ...
# 75%           5952.000000      3832.000000    1980.000000
# max           7325.000000      5234.000000    2387.000000
#
#        Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# count                   65.000000                          65.00
# mean                     8.368462                          11.99
# ...                           ...                            ...
# 75%                      9.030000                          13.54
# max                     12.880000                          20.46
#
#        Cost Per Month - Premium ($)
# count                     65.000000
# mean                      15.612923
# ...                             ...
# 75%                       18.060000
# max                       26.960000
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country_code                   65 non-null     object
#  1   Country                        65 non-null     object
#  2   Total Library Size             65 non-null     int64
#  3   No. of TV Shows                65 non-null     int64
#  4   No. of Movies                  65 non-null     int64
#  5   Cost Per Month - Basic ($)     65 non-null     float64
#  6   Cost Per Month - Standard ($)  65 non-null     float64
#  7   Cost Per Month - Premium ($)   65 non-null     float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 4.2+ KB

# %%
netflix['Country']
# Out:
# 0          Argentina
# 1          Australia
# 2            Austria
# 3            Belgium
# 4            Bolivia
#            ...
# 60           Ukraine
# 61    United Kingdom
# 62     United States
# 63           Uruguay
# 64         Venezuela
# Name: Country, Length: 65, dtype: object

# %%
netflix['Country'][25]
# Out:
# 'Iceland'

# %%
netflix.loc[25]
# Out:
# Country_code                          is
# Country                          Iceland
# Total Library Size                  6387
# No. of TV Shows                     4426
# No. of Movies                       1961
# Cost Per Month - Basic ($)          9.03
# Cost Per Month - Standard ($)      14.67
# Cost Per Month - Premium ($)       20.32
# Name: 25, dtype: object

# %%
netflix.iloc[25]
# Out:
# Country_code                          is
# Country                          Iceland
# Total Library Size                  6387
# No. of TV Shows                     4426
# No. of Movies                       1961
# Cost Per Month - Basic ($)          9.03
# Cost Per Month - Standard ($)      14.67
# Cost Per Month - Premium ($)       20.32
# Name: 25, dtype: object

# %%
netflix.iloc[-2:,-3]
# Out:
# 63    8.99
# 64    7.99
# Name: Cost Per Month - Basic ($), dtype: float64

# %%
import pandas as pd

test =pd.read_excel('./test.xlsx')

test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704
# std       1.113740    30.390071     21.130467   177.625900   455.268042
# ...

# %%
test.info()

pd.set_option('display.max.columns', 80)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
newList =['Id', 'Street', 'YearBuilt','LotArea','SaleCondition','YrSold']


test[newList]
# Out:
#         Id Street  YearBuilt  LotArea SaleCondition  YrSold
# 0     1461   Pave       1961    11622        Normal    2010
# 1     1462   Pave       1958    14267        Normal    2010
# 2     1463   Pave       1997    13830        Normal    2010
# 3     1464   Pave       1998     9978        Normal    2010
# 4     1465   Pave       1992     5005        Normal    2010
# ...    ...    ...        ...      ...           ...     ...
# 1454  2915   Pave       1970     1936        Normal    2006
# 1455  2916   Pave       1970     1894       Abnorml    2006
# 1456  2917   Pave       1960    20000       Abnorml    2006
# 1457  2918   Pave       1992    10441        Normal    2006
# 1458  2919   Pave       1993     9627        Normal    2006
#
# [1459 rows x 6 columns]

# %%
test['YearBuilt']
# Out:
# 0       1961
# 1       1958
# 2       1997
# 3       1998
# 4       1992
#         ...
# 1454    1970
# 1455    1970
# 1456    1960
# 1457    1992
# 1458    1993
# Name: YearBuilt, Length: 1459, dtype: int64
