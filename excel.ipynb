# %%
import pandas as pd

sales = pd.read_csv('./Sales.csv')

sales
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
grouped = sales.groupby(['Country', 'State'])[['Revenue', 'Cost']].sum()

grouped
# Out:
#                                      Revenue     Cost
# Country        State
# Australia      New South Wales       9203495  6069811
#                Queensland            5066267  3447109
#                South Australia       1397274   972435
#                Tasmania               580184   409861
#                Victoria              5054839  3626813
# Canada         Alberta                 56803    33453
#                British Columbia      7877890  4184542
#                Ontario                  1045      447
# France         Charente-Maritime      106047    60047
#                Essonne                973532   579684
#                Garonne (Haute)        183906   110959
#                Hauts de Seine         937140   573003
#                Loir et Cher            82533    49772
#                Loiret                 325172   206681
#                Moselle                266223   166547
#                Nord                  1324652   859107
# ...

# %%
groupedby_M =sales[sales['Customer_Gender'] =='M'

groupedby_M
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 8       2014-02-22   22  February  2014            35  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113029  2015-12-28   28  December  2015            41  Adults (35-64)
# 113030  2014-04-12   12     April  2014            41  Adults (35-64)
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
filtered =sales[(sales['Customer_Gender'] =='M') & (sales['Product_Category']=='Accessories')]

filtered
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 8       2014-02-22   22  February  2014            35  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 108361  2016-04-16   16     April  2016            37  Adults (35-64)
# 108362  2014-06-07    7      June  2014            37  Adults (35-64)
# 108363  2014-06-07    7      June  2014            37  Adults (35-64)
# 108364  2016-06-07    7      June  2016            37  Adults (35-64)
# 108365  2016-06-07    7      June  2016            37  Adults (35-64)
#
#        Customer_Gender    Country              State Product_Category  \
# ...

# %%
groupedby_M = filtered][;groupby(['Country', 'State'])[['Revenue', 'Cost']].sum()

groupedby_M
# Out:
#                                     Revenue    Cost
# Country        State
# Australia      New South Wales       598243  257802
#                Queensland            302747  134800
#                South Australia        94755   43180
#                Tasmania               57721   26554
#                Victoria              413341  195655
# Canada         Alberta                 1790     634
#                British Columbia     1358566  511761
# France         Charente-Maritime      12786    4829
#                Essonne                54250   21228
#                Garonne (Haute)        10464    4253
#                Hauts de Seine         81978   32935
#                Loir et Cher            7934    3304
#                Loiret                 27934   11679
#                Moselle                27334   11632
#                Nord                  100900   43495
#                Pas de Calais           8702    3833
#                Seine (Paris)         131208   59732
# ...
