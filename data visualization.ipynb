# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sportify =pd.read_csv('./spotify - spotify.csv')

sportify.set_index('Date')

#sportify
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
sportify.plot(kind='line', x='Date')
plt.title('My First visualization in pandas')

plt.show()

# %%
sportify.plot(kind='bar')

plt.show()

# %%
sportify.plot(kind='hist')

plt.show()

# %%
eachStreamperDay =sportify.groupby('Date')['Sha']

eachStreamperDay

# %%
sportify =pd.read_csv('./spotify - spotify.csv', index_col='Date')

sportify
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
plt.figure(figsize=(14,6))

plt.title('Daily Global Stream of Popular Song in 2017-2018')

sns.lineplot(data=sportify)
# Out:
# <Axes: title={'center': 'Daily Global Stream of Popular Song in 2017-2018'}, xlabel='Date'>

# %%
list(sportify.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
sportify.rename(columns={"HUMBLE.": "Humble"}, inplace=True)

sportify
# Out:
#             Shape of You  Despacito  Something Just Like This     Humble  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
plt.figure(figsize=(14, 6)) 
plt.title('Most Stream Stong')
sns.lineplot(data=sportify['Shape of You'], label='Shape of You')
sns.lineplot(data=sportify['Humble'], label='Humble')
# Out:
# <Axes: title={'center': 'Most Stream Stong'}, xlabel='Date', ylabel='Shape of You'>

# %%
players =pd.read_csv('./all_players - all_players.csv')

players
# Out:
#        Unnamed: 0              Name          Nation             Club Position  \
# 0               0     Kylian Mbappé          France         Paris SG       ST
# 1               1    Erling Haaland          Norway  Manchester City       ST
# 2               2   Kevin De Bruyne         Belgium  Manchester City       CM
# 3               3      Lionel Messi       Argentina   Inter Miami CF       CF
# 4               4     Karim Benzema          France       Al Ittihad       CF
# ...           ...               ...             ...              ...      ...
# 17321        1476  Kateřina Vithová  Czech Republic     Slavia Praha       LM
# 17322        1477     Lucie Bendová  Czech Republic     Slavia Praha       CB
# 17323        1478    Aleigh Gambone   United States  Glasgow City FC       CM
# 17324        1479        Joy Lysser     Switzerland        FC Zürich       CM
# 17325        1480      Soraya Wulff     Switzerland        FC Zürich       CB
#
# ...
