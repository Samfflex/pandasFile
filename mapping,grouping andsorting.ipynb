# %%
#create a dataframe 
import pandas as pd

Titanic =pd.read_csv('./titanic.csv')

Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
groupby = Titanic.groupby('Pclass')

result = groupby['Survived'].value_counts()

result
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
groupby = Titanic.groupby('Sex')

result = groupby['Pclass'].value_counts()

result
# Out:
# Sex     Pclass
# female  3         144
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: count, dtype: int64

# %%
groupby = Titanic.groupby('Pclass')

result = groupby['Survived'].value_counts()

result
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
groupby = Titanic.groupby('Sex')

result = groupby['Pclass'].median()

result
# Out:
# Sex
# female    2.0
# male      3.0
# Name: Pclass, dtype: float64

# %%
#sorting

sorted_titanic =Titanic.sort_values(by='Age', ascending= False)

sorted_titanic
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
sorted_titanic =Titanic.sort_values(by='Ticket', ascending= False)

sorted_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 745          746         0       1
# 540          541         1       1
# 219          220         0       2
# 92            93         0       1
# 235          236         0       3
# ..           ...       ...     ...
# 585          586         1       1
# 262          263         0       1
# 504          505         1       1
# 257          258         1       1
# 759          760         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 745                       Crosby, Capt. Edward Gifford    male  70.0      1
# 540                            Crosby, Miss. Harriet R  female  36.0      0
# 219                                 Harris, Mr. Walter    male  30.0      0
# 92                         Chaffee, Mr. Herbert Fuller    male  46.0      1
# 235                       Harknett, Miss. Alice Phoebe  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Data Types and Handling Missing Values in Data Analysis

sorted_titanic.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 745          746         0       1
# 540          541         1       1
# 92            93         0       1
# 429          430         1       3
# 292          293         0       2
# ..           ...       ...     ...
# 585          586         1       1
# 262          263         0       1
# 504          505         1       1
# 257          258         1       1
# 759          760         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 745                       Crosby, Capt. Edward Gifford    male  70.0      1
# 540                            Crosby, Miss. Harriet R  female  36.0      0
# 92                         Chaffee, Mr. Herbert Fuller    male  46.0      1
# 429                 Pickard, Mr. Berk (Berk Trembisky)    male  32.0      0
# 292                             Levy, Mr. Rene Jacques    male  36.0      0
# ..                                                 ...     ...   ...    ...
# ...
